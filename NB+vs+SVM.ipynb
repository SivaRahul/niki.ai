# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\niki.ai\\LabelledData.txt",sep=",,,",header=None ,names=['question','type'])
# Out:
# C:\Users\Rahul\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#                                                question          type
# 0     how did serfdom develop in and then leave russ...       unknown
# 1     what films featured the character popeye doyle ?           what
# 2     how can i find a list of celebrities ' real na...       unknown
# 3     what fowl grabs the spotlight after the chines...          what
# 4                      what is the full form of .com ?           what
# 5     what contemptible scoundrel stole the cork fro...          what
# 6     what team did baseball 's st. louis browns bec...          what
# 7                      what is the oldest profession ?           what
# 8                             what are liver enzymes ?           what
# 9     name the scar-faced bounty hunter of the old w...       unknown
# 10                       when was ozzy osbourne born ?           when
# 11     why do heavier objects travel downhill faster ?        unknown
# 12                  who was the pride of the yankees ?            who
# 13                                 who killed gandhi ?            who
# 14    what is considered the costliest disaster the ...          what
# 15    what sprawling u.s. state boasts the most airp...          what
# 16    what did the only repealed amendment to the u....          what
# 17    how many jews were executed in concentration c...       unknown
# 18                     what is `` nine inch nails '' ?           what
# 19                 what is an annotated bibliography ?           what
# 20                    what is the date of boxing day ?           what
# 21    what articles of clothing are tokens in monopo...          what
# 22                            name 11 famous martyrs .        unknown
# 23                         what 's the olympic motto ?           what
# 24       what is the origin of the name ` scarlett ' ?           what
# 25     what 's the second-most-used vowel in english ?           what
# 26               who was the inventor of silly putty ?            who
# 27    what is the highest waterfall in the united st...          what
# 28                name a golf course in myrtle beach .        unknown
# 29           which two states enclose chesapeake bay ?        unknown
# ...                                                 ...           ...
# 1453  can an extended warranty be purchased for this...   affirmation
# 1454                       is the freezer frost free ?    affirmation
# 1455            could someone give me the dimensions ?    affirmation
# 1456             are these drip pans dishwasher safe ?    affirmation
# 1457            do these cooktops require 220 outlet ?    affirmation
# 1458  will this work to connect a wgd9200sq0 to a wf...   affirmation
# 1459  does it work for whirlpool duet ht - washer/dr...   affirmation
# 1460  does the old stack kit fit on the new washer a...   affirmation
# 1461                   is this downdraft ventilation ?    affirmation
# 1462  does the stainless steel trim get scratched by...   affirmation
# 1463  would this work with the whirlpool duet sports...   affirmation
# 1464                               is it made in usa ?    affirmation
# 1465                  is the cooking grate removable ?    affirmation
# 1466  can the cooking grate be removed from the ring ?    affirmation
# 1467                are the last two numbers the gal ?    affirmation
# 1468            can you verify the dimensions for me ?    affirmation
# 1469           can this tank be used for black water ?    affirmation
# 1470                       can you use on a airplane ?    affirmation
# 1471                     will it fit a 10 ft. ceiling?    affirmation
# 1472                          are the lights dimmable?    affirmation
# 1473                           do you ship item to pr?    affirmation
# 1474                  can i just throw them in trash ?    affirmation
# 1475                        are they made in the usa ?    affirmation
# 1476  do you sell an extension kit available for 10'...   affirmation
# 1477                                      is it loud ?    affirmation
# 1478                            can it be cut to fit ?    affirmation
# 1479                               can it be removed ?    affirmation
# 1480                         does this hose have one ?    affirmation
# 1481                           can i get it in india ?    affirmation
# 1482  would this work on a 2008 ford edge with a nak...   affirmation
#
# [1483 rows x 2 columns]

# %%
type(df['question'])
# Out:
# pandas.core.series.Series

# %%
import re
df['question'] = df['question'].apply(lambda x: x.lower())
df['question'] = df['question'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

# %%
from collections import Counter, defaultdict
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle as pkl
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from nltk.stem import SnowballStemmer
from nltk import word_tokenize
from nltk.corpus import wordnet as wn

# %%
stemmer = SnowballStemmer('english').stem
def stem_tokenize(text):
    return [stemmer(i) for i in word_tokenize(text)]
val_split=0.30
vectorizer = CountVectorizer(analyzer='word',lowercase=True,tokenizer=stem_tokenize)

# %%
X_train = vectorizer.fit_transform(df.question.values)
labels = df['type']
indices = np.arange(X_train.shape[0])
np.random.shuffle(indices)
X_train = X_train[indices]
labels = labels[indices]
nb_validation_samples = int(val_split * X_train.shape[0])

x_train = X_train[:-nb_validation_samples]
y_train = labels[:-nb_validation_samples]
x_val = X_train[-nb_validation_samples:]
y_val = labels[-nb_validation_samples:]

clf_nb = MultinomialNB()
clf_nb.fit(x_train,y_train)

preds_nb = clf_nb.predict(x_val)
print(classification_report(preds_nb,y_val))
print("Accuracy :",clf_nb.score(x_val,y_val))
# Out:
#               precision    recall  f1-score   support
#
#          who       0.00      0.00      0.00         0
#  affirmation       0.64      1.00      0.78        16
#      unknown       0.77      0.88      0.82        68
#         what       0.99      0.83      0.90       209
#         when       0.35      0.92      0.51        12
#          who       0.99      0.95      0.97       139
#
#  avg / total       0.92      0.88      0.89       444
#
# ('Accuracy :', 0.88288288288288286)

# %%
type(df['question'])
# Out:
# pandas.core.series.Series

# %%
from sklearn.svm import LinearSVC
clf_svm = LinearSVC()
clf_svm.fit(x_train,y_train)
preds_svm = clf_svm.predict(x_val)
print(classification_report(preds_svm,y_val))
print("Accuracy :",clf_svm.score(x_val,y_val))
# Out:
#               precision    recall  f1-score   support
#
#          who       0.00      0.00      0.00         0
#  affirmation       0.96      1.00      0.98        24
#      unknown       0.95      0.97      0.96        76
#         what       0.99      0.97      0.98       178
#         when       0.94      0.91      0.92        32
#          who       0.99      0.99      0.99       134
#
#  avg / total       0.98      0.98      0.98       444
#
# ('Accuracy :', 0.97522522522522526)
